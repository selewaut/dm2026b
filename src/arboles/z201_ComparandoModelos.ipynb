# %% [markdown]
# # Comparando Modelos

# %% [markdown]
# Estamos en la  Clase 02
# <br> El objetivo de la materia es lograr la mejor predicción para nuestro probleama, para lo que se probarán pipelines con decenas de alternativas, será indispensable comparar varios modelos predictivos entre sí y decidir cual es el mejor
# <br> La tarea no es tan sencilla

# %% [markdown]
# ## Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# # primero establecer el Runtime de Python 3
# from google.colab import drive
# drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
# Seteo local: correr este notebook desde la raiz del repo o desde src/arboles
if (basename(getwd()) == "arboles") {
  ROOT_DIR <- normalizePath(file.path(getwd(), "../.."), mustWork = TRUE)
} else {
  ROOT_DIR <- normalizePath(getwd(), mustWork = TRUE)
}

DATA_DIR <- file.path(ROOT_DIR, "datasets")
EXP_DIR <- file.path(ROOT_DIR, "exp")
KAGGLE_JSON <- file.path(ROOT_DIR, "kaggle.json")

# %%
DATA_DIR
EXP_DIR
KAGGLE_JSON
# Out:
# [1] "/Users/selewaut/Code Projects/master/dm2026b/datasets"
# [1] "/Users/selewaut/Code Projects/master/dm2026b/exp"
# [1] "/Users/selewaut/Code Projects/master/dm2026b/kaggle.json"

# %%
dir.create(DATA_DIR, recursive = TRUE, showWarnings = FALSE)
dir.create(EXP_DIR, recursive = TRUE, showWarnings = FALSE)

dataset_local <- file.path(DATA_DIR, "dataset_pequeno.csv")
if (!file.exists(dataset_local)) {
  stop("No encuentro el dataset en: ", dataset_local)
}

if (file.exists(KAGGLE_JSON)) {
  kaggle_dir <- path.expand("~/.kaggle")
  dir.create(kaggle_dir, recursive = TRUE, showWarnings = FALSE)
  file.copy(KAGGLE_JSON, file.path(kaggle_dir, "kaggle.json"), overwrite = TRUE)
  Sys.chmod(file.path(kaggle_dir, "kaggle.json"), mode = "0600")
} else {
  message("No encontre kaggle.json en la raiz del repo. Solo es necesario para hacer submit a Kaggle.")
}

# %%
# %%shell

# mkdir -p "/content/.drive/My Drive/dm"
# mkdir -p "/content/buckets"
# ln -sfn "/content/.drive/My Drive/dm"   /content/buckets/b1

# mkdir -p ~/.kaggle
# cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
# chmod 600 ~/.kaggle/kaggle.json


# mkdir -p /content/buckets/b1/exp
# mkdir -p /content/buckets/b1/datasets
# mkdir -p /content/datasets


# # defino funcion descargar()
# descargar() {
#   carpeta_destino="/content/buckets/b1/datasets/"
#   url_origen="https://storage.googleapis.com/open-courses/itba2026-7c9a/dm/"
#   archivo="$1"

#   if ! test -f "$carpeta_destino""$archivo"; then
#     wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
#   fi

#   if ! test -f  "/content/datasets/""$archivo"; then
#     cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
#   fi;
# }


# # hago la descarga efectiva, llamando a descargar()
# descargar  "dataset_pequeno.csv"

# %% [markdown]
# # 1  Particion Training/Testing
# ## Clase 02  Experimento 1

# %% [markdown]
# ## 1.1  Objetivos
# Dado que es el primer experimento de la asignatura, acercar a l@s estudiantes las mejores prácticas de operación del ambiente de Google Cloud, realizando una minuciosa demostración en vivo narrando todas las consideraciones pertinentes para evitar accidentes, daños a terceros y a equipos.
# Dar soporte en el acto a  l@s estudiantes que necesitan ayuda para terminar de configurar el ambiente Google Cloud .
# <br>Repaso del concepto de  partición de un dataset al azar, estratificada en la clase
# <br>Dado que es el primer script que se mostrará en vivo a l@s estudiantes,  realizar una visita guiada del  mismo, su estructura y detalles.
# <br>Repaso del algoritmo Arbol de Decisión sus hiperparámetros, y la implementación con la librería  rpart.  Funciones  rpart::rpart  y rpart::predict
# <br>Concepto de replicabilidad de los experimentos mediante las semillas de los generadores de secuencias de números pseudoaleatorios.
# <br>Finalmente, el principal objetivo de este experimento es lograr que l@s estudiantes dimensionen la enorme variabilidad del error de medición de la ganancia de un árbol de decisión al realizar una partición <training, testing>,  contener la sorpresa de los estudiantes, descartar a la simple particion <training, testing> como método,  y construir en conjunto una solucion natural al problema.

# %% [markdown]
# ## 1.2 Introduccion

# %% [markdown]
# ![Particiohn Training/Testing](https://storage.googleapis.com/open-courses/austral2026-5da5/labo1/C2_E1_particion.jpg)

# %% [markdown]
# ![Dos tipos de error](https://storage.googleapis.com/open-courses/austral2026-5da5/labo1/C2_E1_target.jpg)

# %% [markdown]
# ## 1.3  Bibliografía
#
# Demšar, J. [Statistical comparisons of classifiers over multiple data sets](https://www.jmlr.org/papers/volume7/demsar06a/demsar06a.pdf) J. Mach. Learn. Res. 7, 1–30 (2006).
# Starmer, J. [Machine Learning Fundamentals: Cross Validation](https://www.youtube.com/watch?v=fSytzGwwBVw)Machine Learning Fundamentals: Cross Validation, StatQuest with Josh Starmer youtube channel, (2018)
# Hastie, T.[The elements of statistical learning: data mining, inference, and prediction](https://hastie.su.domains/Papers/ESLII.pdf) , volume 2. Springer, 2009  ( Chapter 7 Model Assessment and Selection )

# %% [markdown]
# ## 1.4 Codigo

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# # limpio la memoria
# rm(list=ls(all.names=TRUE)) # remove all objects
# gc(full=TRUE, verbose=FALSE) # garbage collection

# %%
Sys.time()

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla  debe tener su primer semilla aleatoria

# %%
PARAM <- list()
PARAM$semilla <- 300089  # aqui debe ir su primer semilla
PARAM$training_pct <- 70L  # entre  1L y 99L

PARAM$rpart <- list (
  "cp" = -1, # complejidad minima
  "minsplit" = 170, # minima cantidad de regs en un nodo para hacer el split
  "minbucket" = 70, # minima cantidad de regs en una hoja
  "maxdepth" = 7 # profundidad máxima del arbol
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
# carpeta de trabajo
experimento <- "exp201"
dir.create(file.path(EXP_DIR, experimento), recursive = TRUE, showWarnings=FALSE)
setwd(file.path(EXP_DIR, experimento))

# %%
# lectura del dataset
dataset <- fread(file.path(DATA_DIR, "dataset_pequeno.csv"))

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
# particiono estratificadamente el dataset 70%, 30%
particionar(dataset,
  division = c(PARAM$training_pct, 100L -PARAM$training_pct),
  agrupa = "clase_ternaria",
  seed = PARAM$semilla # aqui se usa SU semilla
)

# %%
# genero el modelo
# quiero predecir clase_ternaria a partir del resto
# fold==1  es training,  el 70% de los datos
modelo <- rpart("clase_ternaria ~ .",
  data = dataset[fold == 1],  # fold==1  es training, el 70% de los datos
  xval = 0,
  control = PARAM$rpart # aqui van los parametros
)

# %%
# aplico el modelo a los datos de testing
prediccion <- predict(modelo, # el modelo que genere recien
  dataset[fold == 2], # fold==2  es testing, el 30% de los datos
  type = "prob"
) # type= "prob"  es que devuelva la probabilidad

# %%
tb_prediccion <- as.data.table(list(
  "clase_ternaria"=dataset[fold == 2, clase_ternaria],
  "prob"=prediccion[, "BAJA+2"]
))

# %%
# calculo la ganancia de cada registro
tb_prediccion[, ganancia := ifelse(clase_ternaria == "BAJA+2", 975000, -25000)]

# %%
# calculo la clase
tb_prediccion[, Predicted := prob > (1/40) ]

# %%
ganancia_test <-  tb_prediccion[ Predicted==TRUE,  sum(ganancia)]

# %%
# normalizo la ganancia
ganancia_test_normalizada <- ganancia_test / (( 100 - PARAM$training_pct ) / 100 )

# %%
estimulos <- tb_prediccion[ Predicted==TRUE, .N]
aciertos <- tb_prediccion[ Predicted & clase_ternaria == "BAJA+2", .N]

# %%
# Resultado Final
cat("Testing total: ", dataset[fold == 2, .N], "\n")
cat("Testing BAJA+2: ", dataset[fold == 2 & clase_ternaria == "BAJA+2", .N], "\n")

cat("Estimulos: ", estimulos, "\n")
cat("Aciertos (BAJA+2): ", aciertos, "\n")

cat("Ganancia en testing (normalizada): ", ganancia_test_normalizada, "\n")

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  *Ganancia en testing (normalizada)* <br> en la planilla colaborativa hoja  **C2-1sem**
# * Se discutirá en clase la variabilidad de las ganancias obtenidas de distintos alumnos

# %% [markdown]
# ---

# %% [markdown]
# # 2  Medición Monte Carlo Cross Validation
# ## Clase 02  Experimento 2

# %% [markdown]
# ## 2.1  Objetivos
# Mostrar el funcionamiento de la Montecarlo Cross Validation y que l@s estudiantes aprecien la disminución de la varianza de dicha metodología.
# Relación con el Teorema Central del Límite

# %% [markdown]
# ## 2.2 Introduccion
#
# ![Montecarlo](https://storage.googleapis.com/open-courses/austral2026-5da5/labo1/C2_E2_montecarlo.jpg)
#
# ![Curva normal](https://storage.googleapis.com/open-courses/austral2026-5da5/labo1/C2_E2_normal.jpg)
#
# ![Teorema Central del Limite](https://storage.googleapis.com/open-courses/austral2026-5da5/labo1/C2_E2_teoremacentralLimite.jpg)

# %% [markdown]
# ## 2.3  Bibliografía
#
# Demšar, J. [Statistical comparisons of classifiers over multiple data sets](https://www.jmlr.org/papers/volume7/demsar06a/demsar06a.pdf) J. Mach. Learn. Res. 7, 1–30 (2006).
# Starmer, J. [Machine Learning Fundamentals: Cross Validation](https://www.youtube.com/watch?v=fSytzGwwBVw)Machine Learning Fundamentals: Cross Validation, StatQuest with Josh Starmer youtube channel, (2018)
# Hastie, T.[The elements of statistical learning: data mining, inference, and prediction](https://hastie.su.domains/Papers/ESLII.pdf) , volume 2. Springer, 2009  ( Chapter 7 Model Assessment and Selection )

# %% [markdown]
# ## 2.4 Codigo  Montecarlo

# %% [markdown]
# El código de la Montecarlo Cross Validation es notablemente más complejo que el anterior de una simple partición training/testing
# <br> Se crea la funcion ArbolEstimarGanancia()  que dada una semilla realiza la partición  training/testing, entrena en training, aplica el modelo a testing, y se calculan las ganancias
# <br> Se utiliza la funcion **mcmapply**  de R para aplicar ArbolEstimarGanancia a todos los elementos del vector de semillas

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semillas  debe tener sus cinco semillas aleatorias

# %%
PARAM <- list()
PARAM$semillas <- c(300089, 300109, 300119, 300137, 300149)  # aqui debe ir sus CINCO
PARAM$training_pct <- 70L  # entre  1L y 99L

PARAM$rpart <- list (
  "cp" = -1, # complejidad minima
  "minsplit" = 170, # minima cantidad de regs en un nodo para hacer el split
  "minbucket" = 70, # minima cantidad de regs en una hoja
  "maxdepth" = 7 # profundidad máxima del arbol
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
ArbolEstimarGanancia <- function(semilla, param_basicos) {
  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(param_basicos$training_pct, 100L -param_basicos$training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_basicos$rpart
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion <- predict(modelo, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad

  # prediccion es una matriz con TRES columnas,
  #  llamadas "BAJA+1", "BAJA+2"  y "CONTINUA"
  # cada columna es el vector de probabilidades


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test <- dataset[
    fold == 2,
    sum(ifelse(prediccion[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada <- ganancia_test / (( 100 - PARAM$training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "testing" = dataset[fold == 2, .N],
    "testing_pos" = dataset[fold == 2 & clase_ternaria == "BAJA+2", .N],
    "envios" = dataset[fold == 2, sum(prediccion[, "BAJA+2"] > 0.025)],
    "aciertos" = dataset[
        fold == 2,
        sum(prediccion[, "BAJA+2"] > 0.025 & clase_ternaria == "BAJA+2")
    ],
    "ganancia_test" = ganancia_test_normalizada
  ))
}

# %%
# carpeta de trabajo
experimento <- "exp202"
dir.create(file.path(EXP_DIR, experimento), recursive = TRUE, showWarnings=FALSE)
setwd(file.path(EXP_DIR, experimento))

# %%
# lectura del dataset
dataset <- fread(file.path(DATA_DIR, "dataset_pequeno.csv"))
# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
detectCores()

# %%
# la funcion mcmapply  llama a la funcion ArbolEstimarGanancia
#  tantas veces como valores tenga el vector  PARAM$semillas
salidas <- mcmapply(ArbolEstimarGanancia,
  PARAM$semillas, # paso el vector de semillas
  MoreArgs = list(PARAM), # aqui paso el segundo parametro
  SIMPLIFY = FALSE,
  mc.cores = detectCores() - 2
)

# muestro la lista de las salidas en testing
#  para la particion realizada con cada semilla
salidas

# %%
# paso la lista a vector
tb_salida <- rbindlist(salidas)
print( tb_salida)

# %%
# finalmente calculo la media (promedio)  de las ganancias
cat( "ganancia promedio: ", tb_salida[, mean(ganancia_test)], "\n" )

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  *Ganancia Promedio* <br> en la planilla colaborativa hoja  **C2-5sem**
# * Se discutirá en clase la variabilidad de estos "ganancia promedio de cinco semillas"

# %% [markdown]
# ---

# %% [markdown]
# # 3  Generando n semillas en forma automatica
# ## Clase 02  Experimento 3

# %% [markdown]
# ## 3.1  Objetivos
# Mostrar la creación de nuevas semillas a partir de la librería Primes

# %% [markdown]
# 3.2  Código
#
# Como generar muchas semillas a partir de una

# %%
# instalo y cargo la libreria  primes
if (!require("primes")) install.packages("primes")
require("primes")

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)


set.seed(300089) # inicializo con mi primer semilla

# me quedo con por ejemplo 20 primos al azar
semillas <- sample(primos, 20 )

print( semillas )
# Out:
#  [1] 644857 218249 493747 655103 169327 254083 482371 990917 427417 890429
# [11] 399989 138371 190093 150379 839899 338563 330427 836153 751727 640193

# %% [markdown]
# ---

# %% [markdown]
# # 4  Medición  50-Monte Carlo Cross Validation
# ## Clase 02  Experimento 4

# %% [markdown]
# ## 4.1  Objetivos
# Calcular la ganancia del modelo utilizando 50 semillas nuevas generadas a partir de mi semilla primigenia.

# %% [markdown]
# ## 4.4 Codigo  50 Montecarlo

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# Este punto demora en correr 60 minutos en Google Colab, con lo cual para continuar con el punto siguiente deberá abrir un nuevo Colab asi puede realizar una corrida en paralelo

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

if (!require("primes")) install.packages("primes")
require("primes")

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla_primigenia  debe reemplazarse por SU primer semilla

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 300089
PARAM$qsemillas <- 50
PARAM$training_pct <- 70L  # entre  1L y 99L

PARAM$rpart <- list (
  "cp" = -1, # complejidad minima
  "minsplit" = 170, # minima cantidad de regs en un nodo para hacer el split
  "minbucket" = 70, # minima cantidad de regs en una hoja
  "maxdepth" = 7 # profundidad máxima del arbol
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
ArbolEstimarGanancia <- function(semilla, param_basicos) {
  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(param_basicos$training_pct, 100L -param_basicos$training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_basicos$rpart
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion <- predict(modelo, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad

  # prediccion es una matriz con TRES columnas,
  #  llamadas "BAJA+1", "BAJA+2"  y "CONTINUA"
  # cada columna es el vector de probabilidades


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test <- dataset[
    fold == 2,
    sum(ifelse(prediccion[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada <- ganancia_test / (( 100 - PARAM$training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "testing" = dataset[fold == 2, .N],
    "testing_pos" = dataset[fold == 2 & clase_ternaria == "BAJA+2", .N],
    "envios" = dataset[fold == 2, sum(prediccion[, "BAJA+2"] > 0.025)],
    "aciertos" = dataset[
        fold == 2,
        sum(prediccion[, "BAJA+2"] > 0.025 & clase_ternaria == "BAJA+2")
    ],
    "ganancia_test" = ganancia_test_normalizada
  ))
}

# %%
# carpeta de trabajo
experimento <- "exp204"
dir.create(file.path(EXP_DIR, experimento), recursive = TRUE, showWarnings=FALSE)
setwd(file.path(EXP_DIR, experimento))

# %%
# lectura del dataset
dataset <- fread(file.path(DATA_DIR, "dataset_pequeno.csv"))
# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia) # inicializo

# me quedo con PARAM$qsemillas   semillas
PARAM$semillas <- sample(primos, PARAM$qsemillas )

# %%
PARAM$semillas
# Out:
#  [1] 644857 218249 493747 655103 169327 254083 482371 990917 427417 890429
# [11] 399989 138371 190093 150379 839899 338563 330427 836153 751727 640193
# [21] 759911 528167 333349 425701 106103 320303 726787 881411 308137 465739
# [31] 328333 860941 146197 873421 359041 995399 420037 329123 912797 378551
# [41] 704393 990523 115631 665069 941791 780679 336041 335857 433681 320377

# %%
# install.packages("flock")
library(flock)

log_file <- "progreso_experimento.txt"
cat(sprintf("--- Inicio de ejecución: %s ---\n", Sys.time()), file = log_file)

ArbolConFlock <- function(semilla, param, log_path) {
  res <- ArbolEstimarGanancia(semilla, param)
  
  lock <- lock(log_path)
  
  cat(sprintf("[%s] Finalizada semilla: %s\n", Sys.time(), as.character(semilla)),
      file = log_path, append = TRUE)
  
  unlock(lock)
  
  return(res)
}

# aplicamos version con trackeo de semillas / combinacion corridas
salidas <- mcmapply(
  ArbolConFlock,
  PARAM$semillas,
  MoreArgs = list(PARAM, log_file),
  SIMPLIFY = FALSE,
  mc.cores = detectCores() - 2
)

# %%
# la funcion mcmapply  llama a la funcion ArbolEstimarGanancia
#  tantas veces como valores tenga el vector  PARAM$semillas
salidas <- mcmapply(ArbolEstimarGanancia,
  PARAM$semillas, # paso el vector de semillas
  MoreArgs = list(PARAM), # aqui paso el segundo parametro
  SIMPLIFY = FALSE,
  mc.cores = detectCores()
)

# muestro la lista de las salidas en testing
#  para la particion realizada con cada semilla
salidas

# %%
# paso la lista a vector
tb_salida <- rbindlist(salidas)
print( tb_salida)

# %%
# calulo la salida
for( i in seq(10, 50, 10) )
{
  cat( i, "\t", tb_salida[ 1:i, mean(ganancia_test)], "\n" )
}

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  los resultados en la planilla colaborativa hoja  **C2-nsem**
# * Se discutirá en clase la variabilidad de las distintas cantidades de semillas

# %% [markdown]
# ---

# %% [markdown]
# # 5  DiezMil -Monte Carlo Cross Validation
# ## Clase 02  Experimento 5

# %% [markdown]
# Mostrar a los estudiantes el resultado de un experimento en donde se ha corrido una Monte Carlo Cross Validation utilizando diez mil semillas y relacionar la cantidad de semillas con el resultado del Teorema Central del Límite
# <br>Los resultados se muestran en esta misma guia y se comentan en clase,Bajo ningún concepto se solicitará a l@s estudiantes hacer este experimento en clase ya que lleva varias horas en correr.

# %% [markdown]
# Aqui usted NO debe correr absolutamente nada, el experimento ya fue corrido por la cátedra y le muestra los resultados.

# %% [markdown]
# ## 5.1
# Estos resultados han sido corridos por la cátedra, en un dataset similar, lo importante es ver la forma de la curva.
#
# ![Distribucion de las ganancias](https://storage.googleapis.com/open-courses/austral2026-5da5/labo1/C2_E5_distribucion.jpg)

# %% [markdown]
# Por el teorema central del límite, un aumento de 4 veces de la cantidad de registros que se promedian el desvio estandar disminuye 2 veces ,  raiz(4 ) = 2

# %% [markdown]
# No hay acciones a realizar en este punto  5

# %% [markdown]
# # 6 Comparando dos distintos  modelos
# ## Clase 02  Experimento 6

# %% [markdown]
# ## 6.1  Objetivos
# Presentar a los alumnos la dificultad que se presenta ante la comparación de dos modelos, uno posee un poder predictivo claramente mayor al otro.
# Comparación simple de media de ganancias, versus probabilidad que un modelo sea superior a otro.

# %% [markdown]
# ## 6.2 Introduccion
# Estos son los dos arboles de muy distinta profundidad.
# <br>¿Cuál de ellos es mejor? ¿Cuál elijo?
#
# | Hiperparámetro | Arbol 1 | Arbol 2 |
# | --- | --: |  ---: |
# | cp | -1 | -1 |
# |minsplit | 170 | 250 |
# |minbucket | 70 | 125 |
# |maxdepth | 7 | 20 |

# %% [markdown]
# ## 6.3 Codigo dos distintos modelos

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# El tiempo de corrida es de alrededor de 40 minutos

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

if (!require("primes")) install.packages("primes")
require("primes")

require("ggplot2")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: rpart
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: ggplot2

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla_primigenia  debe reemplazarse por SU primer semilla

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 300089
PARAM$qsemillas <- 20
PARAM$training_pct <- 70L     # entre 1 y 100

# %%
# los dos arboles
PARAM$rpart1 <- list (
  "cp" = -1,
  "minsplit" = 170,
  "minbucket" = 70,
  "maxdepth" = 7
)


PARAM$rpart2 <- list (
  "cp" = -1,
  "minsplit" = 250,
  "minbucket" = 125,
  "maxdepth" = 20
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
DosArbolesEstimarGanancia <- function(semilla, training_pct, param_rpart1, param_rpart2) {

  # fuerzo impresion
  print( paste( semilla, Sys.time()) )
  flush.console()

  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(training_pct, 100L -training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo1 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart1
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion1 <- predict(modelo1, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test1 <- dataset[
    fold == 2,
    sum(ifelse(prediccion1[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada1 <- ganancia_test1 / (( 100 - training_pct ) / 100 )

  modelo2 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart2
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion2 <- predict(modelo2, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test2 <- dataset[
    fold == 2,
    sum(ifelse(prediccion2[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada2 <- ganancia_test2 / (( 100 - training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "ganancia1" = ganancia_test_normalizada1,
    "ganancia2" = ganancia_test_normalizada2
  ))
}

# %%
EXP_DIR
# Out:
# [1] "/Users/selewaut/Code Projects/master/dm2026b/exp"

# %%
# carpeta de trabajo
experimento <- "exp207"
dir.create(file.path(EXP_DIR, experimento), recursive = TRUE, showWarnings=FALSE)
setwd(file.path(EXP_DIR, experimento))

# %%
# lectura del dataset
dataset <- fread(file.path(DATA_DIR, "dataset_pequeno.csv"))

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
detectCores()
# Out:
# [1] 18

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia) # inicializo

# me quedo con PARAM$qsemillas   semillas
PARAM$semillas <- sample(primos, PARAM$qsemillas )

PARAM$semillas
# Out:
#  [1] 644857 218249 493747 655103 169327 254083 482371 990917 427417 890429
# [11] 399989 138371 190093 150379 839899 338563 330427 836153 751727 640193

# %%
PARAM$semillas
# Out:
#  [1] 644857 218249 493747 655103 169327 254083 482371 990917 427417 890429
# [11] 399989 138371 190093 150379 839899 338563 330427 836153 751727 640193

# %%
library(parallel)

log_file <- "progreso_experimento.txt"
cat(sprintf("--- Inicio de ejecución: %s ---\n", Sys.time()), file = log_file)

# Simple wrapper adapted to the arguments of DosArbolesEstimarGanancia
DosArbolesConLog <- function(semilla, training_pct, rpart1, rpart2, log_path) {
  # 1. Run your new 2-tree function
  res <- DosArbolesEstimarGanancia(semilla, training_pct, rpart1, rpart2)
  
  # 2. Append progress to log
  cat(sprintf("[%s] Finalizada semilla: %s\n", Sys.time(), as.character(semilla)),
      file = log_path, append = TRUE)
  
  return(res)
}

# Run parallel execution
num_cores <- max(1, detectCores() - 2) # Safe for Google Colab CPU limits

Sys.time()

salidas <- mcmapply(
  DosArbolesConLog,
  PARAM$semillas,
  MoreArgs = list(
    PARAM$training_pct,
    PARAM$rpart1,
    PARAM$rpart2,
    log_file
  ),
  SIMPLIFY = FALSE,
  mc.cores = num_cores
)

Sys.time()
# Out:
# [1] "2026-08-05 23:46:28 -03"
# [1] "2026-08-05 23:48:55 -03"

# %%
# # demora interminables 60 minutos en correr en Google Colab
# Sys.time()

# salidas <- mcmapply( DosArbolesEstimarGanancia,
#   PARAM$semillas, # paso el vector de semillas
#   MoreArgs = list(PARAM$training_pct, PARAM$rpart1, PARAM$rpart2), # aqui paso el segundo parametro
#   SIMPLIFY = FALSE,
#   mc.cores = detectCores() -2
# )

# Sys.time()

# %%
# paso la lista a vector
tb_salida <- rbindlist(salidas)
tb_salida
# Out:
#    semilla ganancia1 ganancia2
# 1  644857  435750000 353583333
# 2  218249  528666667 519166667
# 3  493747  491333333 442666667
# 4  655103  486916667 395166667
# 5  169327  455000000 413750000
# 6  254083  460083333 407500000
# 7  482371  420333333 376000000
# 8  990917  490500000 426750000
# 9  427417  481833333 475333333
# 10 890429  490916667 425666667
# 11 399989  529416667 498416667
# 12 138371  490333333 452250000
# 13 190093  429500000 418000000
# 14 150379  482416667 418000000
# 15 839899  471500000 389833333
# 16 338563  399333333 402333333
# 17 330427  450083333 405000000
# 18 836153  444583333 398583333
# 19 751727  479166667 431166667
# 20 640193  487583333 499500000

# %%
grafico <- ggplot( tb_salida, aes(x=ganancia1)) + geom_density(alpha=0.25, fill="green", color="green")  +
             geom_density(data=tb_salida, aes(x=ganancia2), fill="purple", color="purple",  alpha=0.10)

print(grafico)
# Out:
# plot without title

# %%
# imprimo en un .pdf  que va a la carpeta del experimento
pdf("densidad_dos.pdf")
print(grafico)
dev.off()
# Out:
# pdf
#   2

# %%
print( tb_salida[ , list( "arbol1" = mean( ganancia1),  "arbol2" = mean(ganancia2) ) ] )

print( tb_salida[ , list( "prob( m1 > m2)" = sum(ganancia1 > ganancia2 )/ .N ) ]  )
# Out:
#       arbol1    arbol2
#        <num>     <num>
# 1: 470262500 427433333
#    prob( m1 > m2)
#             <num>
# 1:            0.9

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  los resultados en la planilla colaborativa hoja  **C2-dosModelos**
# * ¿Todos los alumnos hubieran elegido el mismo modelo aun con 20 semillas?

# %% [markdown]
# ---

# %% [markdown]
# # 7 Comparando dos buenos  modelos
# ## Clase 02  Experimento 7

# %% [markdown]
# ## 7.1  Objetivos
# Presentar a los alumnos la dificultad que surge en la comparación de dos muy distintos, pero ambos buenos, modelos predictivos, y el costo computacional asociado a esa comparación
# <br>Comparación simple de media de ganancias, versus probabilidad que un modelo sea superior a otro.
# <br>Limitaciones de la MonteCarlo Cross Validation
# <br>Existencia del Test de Wilcoxon

# %% [markdown]
# ## 7.2 Introduccion
# Estos son los dos arboles de muy distinta profundidad.
# <br>¿Cuál de ellos es mejor? ¿Cuál elijo?
#
# | Hiperparámetro | Arbol 1 | Arbol 2 |
# | --- | --: |  ---: |
# | cp | -1 | -1 |
# |minsplit | 170 | 1900 |
# |minbucket | 70 | 800 |
# |maxdepth | 7 | 3 |

# %% [markdown]
# ## 7.3 Dos buenos modelos

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# El tiempo de corrida es de alrededor de 50 minutos

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

if (!require("primes")) install.packages("primes")
require("primes")

require("ggplot2")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: rpart
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: ggplot2

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla_primigenia  debe reemplazarse por SU primer semilla

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 300089
PARAM$qsemillas <- 50
PARAM$training_pct <- 70L     # entre 1 y 100

# %%
# los dos arboles
PARAM$rpart1 <- list (
  "cp" = -1,
  "minsplit" = 170,
  "minbucket" = 70,
  "maxdepth" = 7
)


PARAM$rpart2 <- list (
  "cp" = -1,
  "minsplit" = 1900,
  "minbucket" = 800,
  "maxdepth" = 3
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
DosArbolesEstimarGanancia <- function(semilla, training_pct, param_rpart1, param_rpart2) {
  # fuerzo impresion
  print( paste( semilla, Sys.time()) )
  flush.console()

  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(training_pct, 100L -training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo1 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart1
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion1 <- predict(modelo1, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test1 <- dataset[
    fold == 2,
    sum(ifelse(prediccion1[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada1 <- ganancia_test1 / (( 100 - training_pct ) / 100 )

  modelo2 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart2
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion2 <- predict(modelo2, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test2 <- dataset[
    fold == 2,
    sum(ifelse(prediccion2[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada2 <- ganancia_test2 / (( 100 - training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "ganancia1" = ganancia_test_normalizada1,
    "ganancia2" = ganancia_test_normalizada2
  ))
}

# %%
# carpeta de trabajo
experimento <- "exp207"
dir.create(file.path(EXP_DIR, experimento), recursive = TRUE, showWarnings=FALSE)
setwd(file.path(EXP_DIR, experimento))

# %%
# lectura del dataset
dataset <- fread(file.path(DATA_DIR, "dataset_pequeno.csv"))

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia) # inicializo

# me quedo con PARAM$qsemillas   semillas
PARAM$semillas <- sample(primos, PARAM$qsemillas )

# %%
library(parallel)

log_file <- "progreso_experimento.txt"
cat(sprintf("--- Inicio de ejecución: %s ---\n", Sys.time()), file = log_file)

# Simple wrapper adapted to the arguments of DosArbolesEstimarGanancia
DosArbolesConLog <- function(semilla, training_pct, rpart1, rpart2, log_path) {
  # 1. Run your new 2-tree function
  res <- DosArbolesEstimarGanancia(semilla, training_pct, rpart1, rpart2)
  
  # 2. Append progress to log
  cat(sprintf("[%s] Finalizada semilla: %s\n", Sys.time(), as.character(semilla)),
      file = log_path, append = TRUE)
  
  return(res)
}

# Run parallel execution
num_cores <- max(1, detectCores() - 2) # Safe for Google Colab CPU limits

Sys.time()

salidas <- mcmapply(
  DosArbolesConLog,
  PARAM$semillas,
  MoreArgs = list(
    PARAM$training_pct,
    PARAM$rpart1,
    PARAM$rpart2,
    log_file
  ),
  SIMPLIFY = FALSE,
  mc.cores = num_cores
)

Sys.time()
# Out:
# [1] "2026-08-05 22:50:12 -03"
# [1] "2026-08-05 22:52:48 -03"

# %%
# la funcion mcmapply  llama a la funcion DosArbolesEstimarGanancia
#  tantas veces como valores tenga el vector  PARAM$semillas
Sys.time()

salidas <- mcmapply( DosArbolesEstimarGanancia,
  PARAM$semillas, # paso el vector de semillas
  MoreArgs = list(PARAM$training_pct, PARAM$rpart1, PARAM$rpart2), # aqui paso el segundo parametro
  SIMPLIFY = FALSE,
  mc.cores = detectCores() - 2
)

Sys.time()
# Out:
# [1] "2026-08-05 22:52:48 -03"
# [1] "2026-08-05 22:55:19 -03"

# %%
# paso la lista a vector
tb_salida <- rbindlist(salidas)
tb_salida
# Out:
#    semilla ganancia1 ganancia2
# 1  644857  435750000 442583333
# 2  218249  528666667 510500000
# 3  493747  491333333 439166667
# 4  655103  486916667 421083333
# 5  169327  455000000 464000000
# 6  254083  460083333 435833333
# 7  482371  420333333 384833333
# 8  990917  490500000 443916667
# 9  427417  481833333 486166667
# 10 890429  490916667 477916667
# 11 399989  529416667 518333333
# 12 138371  490333333 478833333
# 13 190093  429500000 430750000
# 14 150379  482416667 454166667
# 15 839899  471500000 466166667
# 16 338563  399333333 418583333
# 17 330427  450083333 431750000
# 18 836153  444583333 407583333
# 19 751727  479166667 456750000
# 20 640193  487583333 477000000
# 21 759911  489416667 483000000
# 22 528167  419333333 425416667
# 23 333349  470583333 476250000
# 24 425701  489416667 488583333
# 25 106103  500416667 470083333
# 26 320303  492000000 434750000
# 27 726787  467750000 479583333
# 28 881411  494666667 456083333
# 29 308137  442500000 421583333
# 30 465739  448583333 400583333
# 31 328333  492833333 493583333
# 32 860941  481416667 414416667
# 33 146197  434416667 472500000
# 34 873421  466250000 487000000
# 35 359041  492166667 519250000
# 36 995399  412500000 407833333
# 37 420037  442750000 456750000
# 38 329123  482416667 451000000
# 39 912797  452500000 419083333
# 40 378551  471500000 458333333
# 41 704393  520583333 530083333
# 42 990523  473000000 440583333
# 43 115631  504583333 424750000
# 44 665069  464750000 420166667
# 45 941791  485083333 476000000
# 46 780679  508916667 481500000
# 47 336041  422750000 394083333
# 48 335857  472416667 440416667
# 49 433681  524000000 469666667
# 50 320377  454000000 451000000

# %%
grafico <- ggplot( tb_salida, aes(x=ganancia1), fill="green", color="green") + geom_density(alpha=0.25)  +
             geom_density(data=tb_salida, aes(x=ganancia2), fill="purple", color="purple",  alpha=0.10)

print(grafico)
# Out:
# Warning message in fortify(data, ...):
# “Arguments in `...` must be used.
# ✖ Problematic arguments:
# • fill = "green"
# • color = "green"
# ℹ Did you misspell an argument name?”
# plot without title

# %%
# imprimo en un .pdf  que va a la carpeta del experimento
pdf("densidad_dos.pdf")
print(grafico)
dev.off()
# Out:
# pdf
#   2

# %%
# medias de las ganancias
print( tb_salida[ , list( "arbol1" = mean( ganancia1),  "arbol2" = mean(ganancia2) ) ] )
# Out:
#       arbol1    arbol2
#        <num>     <num>
# 1: 471575000 453796667

# %%
# probabilidad que m1 sea mayor a m2
print( tb_salida[ , list( "prob( m1 > m2)" = sum(ganancia1 > ganancia2 )/ .N ) ]  )
# Out:
#    prob( m1 > m2)
#             <num>
# 1:           0.72

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  los resultados en la planilla colaborativa hoja  **C2-dosBuenos**

# %% [markdown]
# ---

# %% [markdown]
# # 8 Test de Wilcoxon
# ## Clase 02  Experimento 8

# %% [markdown]
# ## 8.1  Objetivos
#
# ¿Como calcular la cantidad mínima de semillas que hacen falta para tener cierta certeza que un modelo es superior a otro?

# %% [markdown]
# ## 8.2  Introduccion
#
# Test de Wilcoxon aplicado al caso anterior

# %% [markdown]
# ## 8.3 Codigo Test de Wilcoxon

# %%
rango <- seq(1)

tb_salida[rango, ganancia1]
tb_salida[rango, ganancia2]

wilcox.test(
  tb_salida[rango, ganancia1],
  tb_salida[rango, ganancia2],
  paired= TRUE
)
# Out:
# [1] 435750000
# [1] 442583333
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 0, p-value = 1
# alternative hypothesis: true location shift is not equal to 0

# %%
rango <- seq(2)

tb_salida[rango, ganancia1]
tb_salida[rango, ganancia2]

wilcox.test(
  tb_salida[rango, ganancia1],
  tb_salida[rango, ganancia2],
  paired= TRUE
)
# Out:
# [1] 435750000 528666667
# [1] 442583333 510500000
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 2, p-value = 1
# alternative hypothesis: true location shift is not equal to 0

# %%
rango <- seq(3)

tb_salida[rango, ganancia1]
tb_salida[rango, ganancia2]

wilcox.test(
  tb_salida[rango, ganancia1],
  tb_salida[rango, ganancia2],
  paired= TRUE
)
# Out:
# [1] 435750000 528666667 491333333
# [1] 442583333 510500000 439166667
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 5, p-value = 0.5
# alternative hypothesis: true location shift is not equal to 0

# %%
rango <- seq(4)

tb_salida[rango, ganancia1]
tb_salida[rango, ganancia2]

wilcox.test(
  tb_salida[rango, ganancia1],
  tb_salida[rango, ganancia2],
  paired= TRUE
)
# Out:
# [1] 435750000 528666667 491333333 486916667
# [1] 442583333 510500000 439166667 421083333
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 9, p-value = 0.25
# alternative hypothesis: true location shift is not equal to 0

# %%
rango <- seq(5)

tb_salida[rango, ganancia1]
tb_salida[rango, ganancia2]

wilcox.test(
  tb_salida[rango, ganancia1],
  tb_salida[rango, ganancia2],
  paired= TRUE
)
# Out:
# [1] 435750000 528666667 491333333 486916667 455000000
# [1] 442583333 510500000 439166667 421083333 464000000
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 12, p-value = 0.3125
# alternative hypothesis: true location shift is not equal to 0

# %%
rango <- seq(5)

tb_salida[rango, ganancia1]
tb_salida[rango, ganancia2]

wilcox.test(
  tb_salida[rango, ganancia1],
  tb_salida[rango, ganancia2],
  paired= TRUE
)
# Out:
# [1] 435750000 528666667 491333333 486916667 455000000
# [1] 442583333 510500000 439166667 421083333 464000000
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 12, p-value = 0.3125
# alternative hypothesis: true location shift is not equal to 0

# %%
for( tope  in seq(nrow(tb_salida))) {
  rango <- seq(tope)

  cat( tb_salida[rango, ganancia1] )
  cat( tb_salida[rango, ganancia2] )

  res <- wilcox.test(
    tb_salida[rango, ganancia1],
    tb_salida[rango, ganancia2],
    paired= TRUE
  )

  print(tope)
  print(res)
}
# Out:
# 435750000442583333[1] 1
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 0, p-value = 1
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667442583333 510500000[1] 2
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 2, p-value = 1
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333442583333 510500000 439166667[1] 3
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 5, p-value = 0.5
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667442583333 510500000 439166667 421083333[1] 4
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 9, p-value = 0.25
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08442583333 510500000 439166667 421083333 4.64e+08[1] 5
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 12, p-value = 0.3125
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333442583333 510500000 439166667 421083333 4.64e+08 435833333[1] 6
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 18, p-value = 0.1563
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333[1] 7
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 25, p-value = 0.07813
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667[1] 8
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 33, p-value = 0.03906
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667[1] 9
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 39, p-value = 0.05469
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667[1] 10
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 49, p-value = 0.02734
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333[1] 11
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 60, p-value = 0.01367
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333[1] 12
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 72, p-value = 0.006836
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000[1] 13
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 81, p-value = 0.0105
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667[1] 14
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 95, p-value = 0.005249
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667[1] 15
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 108, p-value = 0.004272
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333[1] 16
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 114, p-value = 0.0155
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000[1] 17
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 130, p-value = 0.009338
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333[1] 18
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 148, p-value = 0.004745
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000[1] 19
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 167, p-value = 0.002399
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08[1] 20
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 186, p-value = 0.001432
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08[1] 21
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 204, p-value = 0.001176
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667[1] 22
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 219, p-value = 0.001673
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000[1] 23
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 234, p-value = 0.002416
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333[1] 24
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 251, p-value = 0.002815
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333[1] 25
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 276, p-value = 0.001453
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000[1] 26
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 302, p-value = 0.0007454
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333[1] 27
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 315, p-value = 0.001687
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333[1] 28
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 343, p-value = 0.0008751
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333[1] 29
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 372, p-value = 0.0004513
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333[1] 30
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 402, p-value = 0.0002316
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333[1] 31
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 424, p-value = 0.0002865
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667[1] 32
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 456, p-value = 0.0001473
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000[1] 33
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 463, p-value = 0.0007033
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08[1] 34
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 477, p-value = 0.00157
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000[1] 35
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 488, p-value = 0.003803
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333[1] 36
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 515, p-value = 0.003492
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000[1] 37
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 531, p-value = 0.005908
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08[1] 38
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 568, p-value = 0.003471
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333[1] 39
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 606, p-value = 0.002021
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333[1] 40
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 641, p-value = 0.001441
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333[1] 41
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 664, p-value = 0.001961
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333[1] 42
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 705, p-value = 0.001136
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08 504583333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333 424750000[1] 43
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 748, p-value = 0.0006216
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08 504583333 464750000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333 424750000 420166667[1] 44
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 792, p-value = 0.0003372
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08 504583333 464750000 485083333442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333 424750000 420166667 4.76e+08[1] 45
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 830, p-value = 0.00026
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08 504583333 464750000 485083333 508916667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333 424750000 420166667 4.76e+08 481500000[1] 46
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 875, p-value = 0.0001472
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08 504583333 464750000 485083333 508916667 422750000442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333 424750000 420166667 4.76e+08 481500000 394083333[1] 47
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 921, p-value = 8.291e-05
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08 504583333 464750000 485083333 508916667 422750000 472416667442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333 424750000 420166667 4.76e+08 481500000 394083333 440416667[1] 48
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 968, p-value = 4.648e-05
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08 504583333 464750000 485083333 508916667 422750000 472416667 5.24e+08442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333 424750000 420166667 4.76e+08 481500000 394083333 440416667 469666667[1] 49
#
# 	Wilcoxon signed rank exact test
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 1017, p-value = 2.461e-05
# alternative hypothesis: true location shift is not equal to 0
#
# 435750000 528666667 491333333 486916667 4.55e+08 460083333 420333333 490500000 481833333 490916667 529416667 490333333 429500000 482416667 471500000 399333333 450083333 444583333 479166667 487583333 489416667 419333333 470583333 489416667 500416667 4.92e+08 467750000 494666667 442500000 448583333 492833333 481416667 434416667 466250000 492166667 412500000 442750000 482416667 452500000 471500000 520583333 4.73e+08 504583333 464750000 485083333 508916667 422750000 472416667 5.24e+08 4.54e+08442583333 510500000 439166667 421083333 4.64e+08 435833333 384833333 443916667 486166667 477916667 518333333 478833333 430750000 454166667 466166667 418583333 431750000 407583333 456750000 4.77e+08 4.83e+08 425416667 476250000 488583333 470083333 434750000 479583333 456083333 421583333 400583333 493583333 414416667 472500000 4.87e+08 519250000 407833333 456750000 4.51e+08 419083333 458333333 530083333 440583333 424750000 420166667 4.76e+08 481500000 394083333 440416667 469666667 4.51e+08[1] 50
#
# 	Wilcoxon signed rank test with continuity correction
#
# data:  tb_salida[rango, ganancia1] and tb_salida[rango, ganancia2]
# V = 1055, p-value = 5.687e-05
# alternative hypothesis: true location shift is not equal to 0

# %% [markdown]
# ---

# %% [markdown]
# # 9 Comparando automaticamente modelos con test de Wilcoxon
# ## Clase 02  Experimento 9

# %% [markdown]
# ## 9.1  Objetivos
#
# Proveer un script que permita comparar dos arboles de decisión con la librería rpart utilizando la menor cantidad de cómputo que permita el Test de Wilxcoxon

# %% [markdown]
# ## 9.2  Introduccion
#
# | Hiperparámetro | Arbol 1 | Arbol 2 |
# | --- | --- |  --- |
# | cp | -1 | -1 |
# |minsplit | 1050 | 650 |
# |minbucket | 550 | 300 |
# |maxdepth |67 | 6 |

# %% [markdown]
# ## 9.3 Codigo comparacion automatica Wilcoxon

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

if (!require("primes")) install.packages("primes")
require("primes")

require("ggplot2")

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla_primigenia  debe reemplazarse por SU primer semilla

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 300089
PARAM$qsemillas_tope <- 50
PARAM$training_pct <- 70L     # entre 1 y 100

# %%
# los dos arboles
PARAM$rpart1 <- list (
  "cp" = -1,
  "minsplit" = 800,
  "minbucket" = 400,
  "maxdepth" = 7
)


PARAM$rpart2 <- list (
  "cp" = -1,
  "minsplit" = 650,
  "minbucket" = 300,
  "maxdepth" = 6
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
DosArbolesEstimarGanancia <- function(semilla, training_pct, param_rpart1, param_rpart2) {
  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(training_pct, 100L -training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo1 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart1
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion1 <- predict(modelo1, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test1 <- dataset[
    fold == 2,
    sum(ifelse(prediccion1[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada1 <- ganancia_test1 / (( 100 - training_pct ) / 100 )

  modelo2 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart2
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion2 <- predict(modelo2, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test2 <- dataset[
    fold == 2,
    sum(ifelse(prediccion2[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada2 <- ganancia_test2 / (( 100 - training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "ganancia1" = ganancia_test_normalizada1,
    "ganancia2" = ganancia_test_normalizada2
  ))
}

# %%
# 1  ->  el modelo 1 es mejor
# 2  ->  el modelo 2 es mejor
# 0  ->  No se pudo determinar con el tope de qsemillas_tope

MejorArbol <- function( qsemillas_tope, training_pct, param_rpart1, param_rpart2) {

  # genero numeros primos
  primos <- generate_primes(min = 100000, max = 1000000)
  set.seed(PARAM$semilla_primigenia) # inicializo
  # me quedo con PARAM$qsemillas   semillas
  semillas <- sample(primos, qsemillas_tope )

  pvalue <- 1.0
  isem <- 1
  vgan1 <- c() # almaceno ganancias del modelo1
  vgan2 <- c() # almaceno ganancias del modelo2

  while( (isem <= qsemillas_tope)  & (pvalue > 0.05) ) {

    res <- DosArbolesEstimarGanancia(
       semillas[ isem ],
       training_pct,
       param_rpart1,
       param_rpart2
    )

    vgan1 <- c( vgan1, res$ganancia1 )
    vgan2 <- c( vgan2, res$ganancia2 )

    wt <- wilcox.test( vgan1, vgan2, paired=TRUE )
    pvalue <- wt$p.value

    cat( isem, res$ganancia1, res$ganancia2, pvalue, "\n" )
    flush.console()
    isem <- isem + 1
  }

  out <- 0

  if( pvalue < 0.05 & mean(vgan1) > mean(vgan2)  )  out <- 1
  if( pvalue < 0.05 & mean(vgan1) < mean(vgan2)  )  out <- 2


  return( list( "out" = out,
    "qsemillas" = length(vgan1),
    "m1" = mean( vgan1 ),
    "m2" = mean( vgan2 )
   ) )
}

# %%
# carpeta de trabajo
experimento <- "exp209"
dir.create(file.path(EXP_DIR, experimento), recursive = TRUE, showWarnings=FALSE)
setwd(file.path(EXP_DIR, experimento))

# %%
# lectura del dataset
dataset <- fread(file.path(DATA_DIR, "dataset_pequeno.csv"))

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
Sys.time()

comparacion <- MejorArbol(
   PARAM$qsemillas_tope,
   PARAM$training_pct,
   PARAM$rpart1,
   PARAM$rpart2
 )


print( comparacion )

Sys.time()
# Out:
# [1] "2026-08-05 22:55:19 -03"
# 1 470166667 461666667 1
# 2 5.47e+08 542750000 0.5
# 3 490166667 461500000 0.25
# 4 452833333 490833333 0.875
# 5 472750000 478916667 1
# 6 481500000 4.72e+08 0.6875
# 7 427666667 442750000 1
# 8 445666667 484916667 0.640625
# 9 523166667 507416667 0.9101562
# 10 479500000 4.59e+08 0.921875
# 11 505916667 514583333 1
# 12 505583333 470250000 0.7910156
# 13 466666667 451333333 0.5878906
# 14 493166667 476583333 0.4262695
# 15 476583333 484666667 0.4542847
# 16 432166667 423833333 0.3754578
# 17 488166667 465083333 0.2633209
# 18 462583333 474250000 0.34655
# 19 467833333 463750000 0.3320656
# 20 509250000 529166667 0.4980087
# 21 550500000 519500000 0.3554163
# 22 462916667 461666667 0.3369474
# 23 483416667 493083333 0.427418
# 24 518583333 494166667 0.3028992
# 25 485583333 487833333 0.3123333
# 26 518833333 477833333 0.1987362
# 27 491083333 510416667 0.2900813
# 28 512416667 507833333 0.2740714
# 29 460916667 4.6e+08 0.2652079
# 30 460083333 431416667 0.1823448
# 31 524500000 550333333 0.2877062
# 32 479833333 498583333 0.3870059
# 33 471333333 463500000 0.3551968
# 34 471416667 484833333 0.4339054
# 35 499500000 5.16e+08 0.5408318
# 36 4.89e+08 450250000 0.3941628
# 37 485333333 466583333 0.3106126
# 38 494250000 469916667 0.227374
# 39 4.42e+08 427750000 0.1859059
# 40 511333333 511166667 0.1797946
# 41 514833333 514750000 0.1723772
# 42 477166667 466250000 0.1456251
# 43 466416667 465250000 0.1377942
# 44 463666667 484666667 0.2003168
# 45 476416667 466416667 0.1709769
# 46 484166667 525916667 0.2835528
# 47 461833333 454666667 0.2590334
# 48 460166667 468166667 0.2924651
# 49 506666667 490583333 0.2398434
# 50 5.05e+08 499666667 0.2220277
# $out
# [1] 0
#
# $qsemillas
# [1] 50
#
# $m1
# [1] 484550000
#
# $m2
# [1] 481485000
# [1] "2026-08-05 23:20:33 -03"

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  los resultados en la planilla colaborativa hoja  **C2-Wilcox**

# %% [markdown]
# ---
